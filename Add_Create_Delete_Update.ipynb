# %%
import pandas as pd
pd.options.display.max_rows= 10

# %%
data = pd.read_csv('summer.csv')

# %%
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
#remove the sports column

# %%
data2 = data.drop(columns='Sport')

# %%
data2
# Out:
#        Year    City           Discipline                    Athlete Country  \
# 0      1896  Athens             Swimming              HAJOS, Alfred     HUN
# 1      1896  Athens             Swimming           HERSCHMANN, Otto     AUT
# 2      1896  Athens             Swimming          DRIVAS, Dimitrios     GRE
# 3      1896  Athens             Swimming         MALOKINIS, Ioannis     GRE
# 4      1896  Athens             Swimming         CHASAPIS, Spiridon     GRE
# ...     ...     ...                  ...                        ...     ...
# 31160  2012  London  Wrestling Freestyle         JANIKOWSKI, Damian     POL
# 31161  2012  London  Wrestling Freestyle  REZAEI, Ghasem Gholamreza     IRI
# 31162  2012  London  Wrestling Freestyle             TOTROV, Rustam     RUS
# 31163  2012  London  Wrestling Freestyle          ALEKSANYAN, Artur     ARM
# 31164  2012  London  Wrestling Freestyle             LIDBERG, Jimmy     SWE
#
#       Gender                       Event   Medal
# ...

# %%
#removing column without new variable

# %%
data3 = data.copy()

# %%
data3.drop(columns=['Sport','Discipline'],inplace=True)

# %%
data3
# Out:
#        Year    City                    Athlete Country Gender  \
# 0      1896  Athens              HAJOS, Alfred     HUN    Men
# 1      1896  Athens           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...                        ...     ...    ...
# 31160  2012  London         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London             TOTROV, Rustam     RUS    Men
# 31163  2012  London          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# 1                  100M Freestyle  Silver
# 2      100M Freestyle For Sailors  Bronze
# 3      100M Freestyle For Sailors    Gold
# ...

# %%
data2.head()
# Out:
#    Year    City Discipline             Athlete Country Gender  \
# 0  1896  Athens   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
data2.drop(labels='Event',axis=1,inplace=True) #axis = 'columns'

# %%
data2.head()
# Out:
#    Year    City Discipline             Athlete Country Gender   Medal
# 0  1896  Athens   Swimming       HAJOS, Alfred     HUN    Men    Gold
# 1  1896  Athens   Swimming    HERSCHMANN, Otto     AUT    Men  Silver
# 2  1896  Athens   Swimming   DRIVAS, Dimitrios     GRE    Men  Bronze
# 3  1896  Athens   Swimming  MALOKINIS, Ioannis     GRE    Men    Gold
# 4  1896  Athens   Swimming  CHASAPIS, Spiridon     GRE    Men  Silver

# %%
#use the del method can work too

# %%
#using slice method

# %%
data4 = data2.loc[:,['Year','City']]

# %%
data4
# Out:
#        Year    City
# 0      1896  Athens
# 1      1896  Athens
# 2      1896  Athens
# 3      1896  Athens
# 4      1896  Athens
# ...     ...     ...
# 31160  2012  London
# 31161  2012  London
# 31162  2012  London
# 31163  2012  London
# 31164  2012  London
#
# [31165 rows x 2 columns]

# %%
#removing rows

# %%
data.head(1)
# Out:
#    Year    City     Sport Discipline        Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
#
#             Event Medal
# 0  100M Freestyle  Gold

# %%
data= pd.read_csv('summer.csv',index_col='Athlete')

# %%
data.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
data2 = data.drop(index = 'HAJOS, Alfred')

# %%
data2.head(4)
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
##
#Adding Columns

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
data_add = data.loc[:,['survived','sex','age']]

# %%
data_add.head()
# Out:
#    survived     sex   age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
#columns name

# %%
data_add['New Column'] = 'New Column'

# %%
data_add
# Out:
#      survived     sex   age  New Column
# 0           0    male  22.0  New Column
# 1           1  female  38.0  New Column
# 2           1  female  26.0  New Column
# 3           1  female  35.0  New Column
# 4           0    male  35.0  New Column
# ..        ...     ...   ...         ...
# 886         0    male  27.0  New Column
# 887         1  female  19.0  New Column
# 888         0  female   NaN  New Column
# 889         1    male  26.0  New Column
# 890         0    male  32.0  New Column
#
# [891 rows x 4 columns]

# %%
data_add['YoB'] = 1912 - data_add['age']

# %%
data_add
# Out:
#      survived     sex   age  New Column     YoB
# 0           0    male  22.0  New Column  1890.0
# 1           1  female  38.0  New Column  1874.0
# 2           1  female  26.0  New Column  1886.0
# 3           1  female  35.0  New Column  1877.0
# 4           0    male  35.0  New Column  1877.0
# ..        ...     ...   ...         ...     ...
# 886         0    male  27.0  New Column  1885.0
# 887         1  female  19.0  New Column  1893.0
# 888         0  female   NaN  New Column     NaN
# 889         1    male  26.0  New Column  1886.0
# 890         0    male  32.0  New Column  1880.0
#
# [891 rows x 5 columns]

# %%
data_add['Relatives'] = data['sibsp'] + data['parch']

# %%
data_add
# Out:
#      survived     sex   age  New Column     YoB  Relatives
# 0           0    male  22.0  New Column  1890.0          1
# 1           1  female  38.0  New Column  1874.0          1
# 2           1  female  26.0  New Column  1886.0          0
# 3           1  female  35.0  New Column  1877.0          1
# 4           0    male  35.0  New Column  1877.0          0
# ..        ...     ...   ...         ...     ...        ...
# 886         0    male  27.0  New Column  1885.0          0
# 887         1  female  19.0  New Column  1893.0          0
# 888         0  female   NaN  New Column     NaN          3
# 889         1    male  26.0  New Column  1886.0          0
# 890         0    male  32.0  New Column  1880.0          0
#
# [891 rows x 6 columns]

# %%
data_add.drop(columns=['New Column'],inplace=True)

# %%
data_add
# Out:
#      survived     sex   age     YoB  Relatives
# 0           0    male  22.0  1890.0          1
# 1           1  female  38.0  1874.0          1
# 2           1  female  26.0  1886.0          0
# 3           1  female  35.0  1877.0          1
# 4           0    male  35.0  1877.0          0
# ..        ...     ...   ...     ...        ...
# 886         0    male  27.0  1885.0          0
# 887         1  female  19.0  1893.0          0
# 888         0  female   NaN     NaN          3
# 889         1    male  26.0  1886.0          0
# 890         0    male  32.0  1880.0          0
#
# [891 rows x 5 columns]

# %%
#insert() column

# %%
data_add.insert(loc=5,column='Fare',value=data['fare'])

# %%
data_add
# Out:
#      survived     sex   age     YoB  Relatives     Fare
# 0           0    male  22.0  1890.0          1   7.2500
# 1           1  female  38.0  1874.0          1  71.2833
# 2           1  female  26.0  1886.0          0   7.9250
# 3           1  female  35.0  1877.0          1  53.1000
# 4           0    male  35.0  1877.0          0   8.0500
# ..        ...     ...   ...     ...        ...      ...
# 886         0    male  27.0  1885.0          0  13.0000
# 887         1  female  19.0  1893.0          0  30.0000
# 888         0  female   NaN     NaN          3  23.4500
# 889         1    male  26.0  1886.0          0  30.0000
# 890         0    male  32.0  1880.0          0   7.7500
#
# [891 rows x 6 columns]
