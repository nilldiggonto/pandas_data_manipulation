# %%
#pandas library

# %%
import pandas as pd

# %%
data = pd.read_csv('summer.csv') #olympic summer data set

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Athlete       31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
data.describe() #only Year column has the int64 type
# Out:
#                Year
# count  31165.000000
# mean    1970.482785
# std       33.158416
# min     1896.000000
# 25%     1948.000000
# 50%     1980.000000
# 75%     2000.000000
# max     2012.000000

# %%
#defining index

# %%
data_by_athlete = pd.read_csv('summer.csv', index_col='Athlete')

# %%
data_by_athlete.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
data_by_athlete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
#selecting rows

# %%
data_by_athlete.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
data_by_athlete.loc['HAJOS, Alfred']
# Out:
#                Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
#                          Event Medal
# Athlete
# HAJOS, Alfred   100M Freestyle  Gold
# HAJOS, Alfred  1200M Freestyle  Gold

# %%
data_by_athlete.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
data_by_athlete.loc['LIDBERG, Jimmy']
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
data_by_athlete.iloc[1:3] #slicing rows
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
data_by_athlete.iloc[[1,2]]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
#first 8 rows

# %%
data_by_athlete.iloc[:8]
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# HERSCHMANN, Otto                   100M Freestyle  Silver
# DRIVAS, Dimitrios      100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# ...

# %%
#last 8 rows

# %%
data_by_athlete.iloc[-8:]
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# KHUGAEV, Alan                 2012  London  Wrestling  Wrestling Freestyle
# EBRAHIM, Karam Mohamed Gaber  2012  London  Wrestling  Wrestling Freestyle
# GAJIYEV, Danyal               2012  London  Wrestling  Wrestling Freestyle
# JANIKOWSKI, Damian            2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza     2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam                2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur             2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy                2012  London  Wrestling  Wrestling Freestyle
#
#                              Country Gender     Event   Medal
# Athlete
# KHUGAEV, Alan                    RUS    Men  Wg 84 KG    Gold
# EBRAHIM, Karam Mohamed Gaber     EGY    Men  Wg 84 KG  Silver
# GAJIYEV, Danyal                  KAZ    Men  Wg 84 KG  Bronze
# ...

# %%
#selecting columns

# %%
data_by_athlete.head(3)
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred      1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HAJOS, Alfred                  100M Freestyle    Gold
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
#selecting only country for "HERSCHMANN, Otto"

# %%
data_by_athlete.loc['HERSCHMANN, Otto','Country']
# Out:
# Athlete
# HERSCHMANN, Otto    AUT
# HERSCHMANN, Otto    AUT
# Name: Country, dtype: object

# %%
data_by_athlete.iloc[1,4]
# Out:
# 'AUT'

# %%
data_by_athlete.iloc[1,:3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HERSCHMANN, Otto, dtype: object

# %%
data_by_athlete.iloc[1:3,:3]
# Out:
#                    Year    City     Sport
# Athlete
# HERSCHMANN, Otto   1896  Athens  Aquatics
# DRIVAS, Dimitrios  1896  Athens  Aquatics

# %%
#iloc is position based and loc is label based

# %%
data_by_athlete.head(1
                    )
# Out:
#                Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
#
#                         Event Medal
# Athlete
# HAJOS, Alfred  100M Freestyle  Gold

# %%
data_by_athlete.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
data_by_athlete.loc['PHELPS, Michael'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, PHELPS, Michael to PHELPS, Michael
# Data columns (total 8 columns):
# Year          22 non-null int64
# City          22 non-null object
# Sport         22 non-null object
# Discipline    22 non-null object
# Country       22 non-null object
# Gender        22 non-null object
# Event         22 non-null object
# Medal         22 non-null object
# dtypes: int64(1), object(7)
# memory usage: 1.5+ KB

# %%
data_by_athlete.loc[['PHELPS, Michael','HERSCHMANN, Otto'],['Country','Event']]
# Out:
#                  Country                   Event
# Athlete
# PHELPS, Michael      USA          100M Butterfly
# PHELPS, Michael      USA          200M Butterfly
# PHELPS, Michael      USA          200M Freestyle
# PHELPS, Michael      USA  200M Individual Medley
# PHELPS, Michael      USA  400M Individual Medley
# PHELPS, Michael      USA  4X100M Freestyle Relay
# PHELPS, Michael      USA     4X100M Medley Relay
# PHELPS, Michael      USA  4X200M Freestyle Relay
# PHELPS, Michael      USA          100M Butterfly
# PHELPS, Michael      USA          200M Butterfly
# PHELPS, Michael      USA          200M Freestyle
# PHELPS, Michael      USA  200M Individual Medley
# PHELPS, Michael      USA  400M Individual Medley
# PHELPS, Michael      USA  4X100M Freestyle Relay
# PHELPS, Michael      USA     4X100M Medley Relay
# PHELPS, Michael      USA  4X200M Freestyle Relay
# PHELPS, Michael      USA          100M Butterfly
# PHELPS, Michael      USA          200M Butterfly
# ...

# %%
#reindex

# %%
#only work when we don't have any duplicate index

# %%
data.reindex(index=[40000,'Nill'],columns=['Country','Event','Nothing'])
# Out:
#       Country Event  Nothing
# 40000     NaN   NaN      NaN
# Nill      NaN   NaN      NaN

# %%
data_by_athlete.reindex(columns=['Age','Something'])
# Out:
#                                    Age  Something
# Athlete
# HAJOS, Alfred                      NaN        NaN
# HERSCHMANN, Otto                   NaN        NaN
# DRIVAS, Dimitrios                  NaN        NaN
# MALOKINIS, Ioannis                 NaN        NaN
# CHASAPIS, Spiridon                 NaN        NaN
# CHOROPHAS, Efstathios              NaN        NaN
# HAJOS, Alfred                      NaN        NaN
# ANDREOU, Joannis                   NaN        NaN
# CHOROPHAS, Efstathios              NaN        NaN
# NEUMANN, Paul                      NaN        NaN
# PEPANOS, Antonios                  NaN        NaN
# LANE, Francis                      NaN        NaN
# SZOKOLYI, Alajos                   NaN        NaN
# BURKE, Thomas                      NaN        NaN
# HOFMANN, Fritz                     NaN        NaN
# CURTIS, Thomas                     NaN        NaN
# GOULDING, Grantley                 NaN        NaN
# LERMUSIAUX, Albin                  NaN        NaN
# ...
