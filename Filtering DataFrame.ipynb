# %%
#lib

# %%
import pandas as pd
pd.options.display.max_rows= 10

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#checking nlarge and nsmall

# %%
age = data['age']

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age.sort_values(ascending=False).head(10)
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
# 745    70.0
# 672    70.0
# 33     66.0
# 456    65.0
# 280    65.0
# Name: age, dtype: float64

# %%
#largest

# %%
age.nlargest()
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
# Name: age, dtype: float64

# %%
age.nsmallest()
# Out:
# 803    0.42
# 755    0.67
# 469    0.75
# 644    0.75
# 78     0.83
# Name: age, dtype: float64

# %%
#idxmin #idxmax

# %%
age.idxmax()
# Out:
# 630

# %%
age.idxmin()
# Out:
# 803

# %%
age.iloc[630]
# Out:
# 80.0

# %%
age.iloc[803]
# Out:
# 0.42

# %%
#filter all male passenger

# %%
data['sex'].head(10)
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# 5      male
# 6      male
# 7      male
# 8    female
# 9    female
# Name: sex, dtype: object

# %%
data['sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
data[data['sex']=='male']
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0           0       3  male  22.0      1      0   7.2500        S  NaN
# 4           0       3  male  35.0      0      0   8.0500        S  NaN
# 5           0       3  male   NaN      0      0   8.4583        Q  NaN
# 6           0       1  male  54.0      0      0  51.8625        S    E
# 7           0       3  male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...   ...   ...    ...    ...      ...      ...  ...
# 883         0       2  male  28.0      0      0  10.5000        S  NaN
# 884         0       3  male  25.0      0      0   7.0500        S  NaN
# 886         0       2  male  27.0      0      0  13.0000        S  NaN
# 889         1       1  male  26.0      0      0  30.0000        C    C
# 890         0       3  male  32.0      0      0   7.7500        Q  NaN
#
# [577 rows x 9 columns]

# %%
only_male = data['sex'] =='male'

# %%
only_male
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
data.loc[only_male]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0           0       3  male  22.0      1      0   7.2500        S  NaN
# 4           0       3  male  35.0      0      0   8.0500        S  NaN
# 5           0       3  male   NaN      0      0   8.4583        Q  NaN
# 6           0       1  male  54.0      0      0  51.8625        S    E
# 7           0       3  male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...   ...   ...    ...    ...      ...      ...  ...
# 883         0       2  male  28.0      0      0  10.5000        S  NaN
# 884         0       3  male  25.0      0      0   7.0500        S  NaN
# 886         0       2  male  27.0      0      0  13.0000        S  NaN
# 889         1       1  male  26.0      0      0  30.0000        C    C
# 890         0       3  male  32.0      0      0   7.7500        Q  NaN
#
# [577 rows x 9 columns]

# %%
#get all the fare for male

# %%
male_fare =data.loc[data['sex']=='male','fare']

# %%
male_fare.describe()
# Out:
# count    577.000000
# mean      25.523893
# std       43.138263
# min        0.000000
# 25%        7.895800
# 50%       10.500000
# 75%       26.550000
# max      512.329200
# Name: fare, dtype: float64

# %%
male_fare.to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 890
# Data columns (total 1 columns):
# fare    577 non-null float64
# dtypes: float64(1)
# memory usage: 9.0 KB

# %%
#filtering data type

# %%
data.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
data_type = data.dtypes == object

# %%
data_type
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
data.loc[:,data_type]
# Out:
#         sex embarked deck
# 0      male        S  NaN
# 1    female        C    C
# 2    female        S  NaN
# 3    female        S    C
# 4      male        S  NaN
# ..      ...      ...  ...
# 886    male        S  NaN
# 887  female        S    B
# 888  female        S  NaN
# 889    male        C    C
# 890    male        Q  NaN
#
# [891 rows x 3 columns]

# %%
data.loc[:,~data_type] #exclude object datatype
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
data.loc[only_male,~data_type] #only male all numeric value
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 4           0       3  35.0      0      0   8.0500
# 5           0       3   NaN      0      0   8.4583
# 6           0       1  54.0      0      0  51.8625
# 7           0       3   2.0      3      1  21.0750
# ..        ...     ...   ...    ...    ...      ...
# 883         0       2  28.0      0      0  10.5000
# 884         0       3  25.0      0      0   7.0500
# 886         0       2  27.0      0      0  13.0000
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [577 rows x 6 columns]

# %%
#two conditional filter

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#get all female whoes age is greater than 12v

# %%
female_data = data['sex'] == 'female'

# %%
female_data
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
age_female = data['age'] >12

# %%
age_female
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
(female_data & age_female)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
new_data = data.loc[female_data & age_female,['survived','pclass','sex','age']]

# %%
new_data
# Out:
#      survived  pclass     sex   age
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 8           1       3  female  27.0
# 9           1       2  female  14.0
# ..        ...     ...     ...   ...
# 879         1       1  female  56.0
# 880         1       2  female  25.0
# 882         0       3  female  22.0
# 885         0       3  female  39.0
# 887         1       1  female  19.0
#
# [229 rows x 4 columns]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 1 to 887
# Data columns (total 4 columns):
# survived    229 non-null int64
# pclass      229 non-null int64
# sex         229 non-null object
# age         229 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 8.9+ KB

# %%
new_data.describe()
# Out:
#          survived      pclass         age
# count  229.000000  229.000000  229.000000
# mean     0.777293    1.978166   31.146288
# std      0.416975    0.845242   11.844913
# min      0.000000    1.000000   13.000000
# 25%      1.000000    1.000000   22.000000
# 50%      1.000000    2.000000   29.000000
# 75%      1.000000    3.000000   39.000000
# max      1.000000    3.000000   63.000000

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#more filter

# %%
data2 = pd.read_csv('summer.csv')
data2.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
data_1988 = data2.loc[data2['Year']==1988]

# %%
data_1988
# Out:
#        Year   City      Sport       Discipline                      Athlete  \
# 18051  1988  Seoul   Aquatics           Diving           MENA CAMPOS, Jesus
# 18052  1988  Seoul   Aquatics           Diving            LOUGANIS, Gregory
# 18053  1988  Seoul   Aquatics           Diving                    XIONG, Ni
# 18054  1988  Seoul   Aquatics           Diving  WYLAND-WILLIAMS, Wendy Lian
# 18055  1988  Seoul   Aquatics           Diving                  XU, Yan-Mei
# ...     ...    ...        ...              ...                          ...
# 19592  1988  Seoul  Wrestling  Wrestling Gre-R       KOMCHEV, Atanas Slavov
# 19593  1988  Seoul  Wrestling  Wrestling Gre-R        KOSKELA, Harri Matias
# 19594  1988  Seoul  Wrestling  Wrestling Gre-R     KOSLOWSKI, Dennis Marvin
# 19595  1988  Seoul  Wrestling  Wrestling Gre-R             WRONSKI, Andrzej
# 19596  1988  Seoul  Wrestling  Wrestling Gre-R              HIMMEL, Gerhard
#
# ...

# %%
data_1988.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1546 entries, 18051 to 19596
# Data columns (total 9 columns):
# Year          1546 non-null int64
# City          1546 non-null object
# Sport         1546 non-null object
# Discipline    1546 non-null object
# Athlete       1546 non-null object
# Country       1546 non-null object
# Gender        1546 non-null object
# Event         1546 non-null object
# Medal         1546 non-null object
# dtypes: int64(1), object(8)
# memory usage: 120.8+ KB

# %%
data_since1992 = data2.loc[data2['Year']>=1992]

# %%
data_since1992
# Out:
#        Year       City      Sport           Discipline  \
# 19597  1992  Barcelona   Aquatics               Diving
# 19598  1992  Barcelona   Aquatics               Diving
# 19599  1992  Barcelona   Aquatics               Diving
# 19600  1992  Barcelona   Aquatics               Diving
# 19601  1992  Barcelona   Aquatics               Diving
# ...     ...        ...        ...                  ...
# 31160  2012     London  Wrestling  Wrestling Freestyle
# 31161  2012     London  Wrestling  Wrestling Freestyle
# 31162  2012     London  Wrestling  Wrestling Freestyle
# 31163  2012     London  Wrestling  Wrestling Freestyle
# 31164  2012     London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender         Event   Medal
# 19597                  XIONG, Ni     CHN    Men  10M Platform  Bronze
# 19598                SUN, Shuwei     CHN    Men  10M Platform    Gold
# 19599            DONIE, Scott R.     USA    Men  10M Platform  Silver
# ...

# %%
data_60to69 = data2['Year'].between(1960,1969,inclusive=True)

# %%
data_60to69
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Name: Year, Length: 31165, dtype: bool

# %%
data_60to69_new = data2.loc[data_60to69]

# %%
data_60to69_new
# Out:
#        Year    City      Sport       Discipline                      Athlete  \
# 9792   1960    Rome   Aquatics           Diving           PHELPS, Brian Eric
# 9793   1960    Rome   Aquatics           Diving        WEBSTER, Robert David
# 9794   1960    Rome   Aquatics           Diving         TOBIAN, Gary Milburn
# 9795   1960    Rome   Aquatics           Diving               KRUTOVA, Ninel
# 9796   1960    Rome   Aquatics           Diving  KRÄMER-ENGEL-GULBIN, Ingrid
# ...     ...     ...        ...              ...                          ...
# 12710  1968  Mexico  Wrestling  Wrestling Gre-R                 METZ, Lothar
# 12711  1968  Mexico  Wrestling  Wrestling Gre-R            OLEINIK, Valentin
# 12712  1968  Mexico  Wrestling  Wrestling Gre-R          MARTINESCU, Nicolae
# 12713  1968  Mexico  Wrestling  Wrestling Gre-R     RADEV, Boyan Aleksandrov
# 12714  1968  Mexico  Wrestling  Wrestling Gre-R           YAKOVENKO, Nikolai
#
# ...

# %%
#between method #isin method #and #or
